# %%
import pandas as pd

# %%
df_degree = pd.read_csv("C:/Users/admin/Desktop/degrees.csv")

# %%
df_des=pd.read_csv("C:/Users/admin/Desktop/people_descriptions.csv")

# %%
df_people=pd.read_csv("C:/Users/admin/Desktop/people.csv")

# %%
df_degree.head(2)
# Out:
#                                    uuid  \
# 0  205fdfd1-ecac-aa43-262f-219f11755f67
# 1  1a2ac288-eb99-3318-fde5-1517bc168f51
#
#                                                 name    type  permalink  \
# 0         MS  Mass Communication @ Boston University  degree        NaN
# 1  BA  English, French @ Washington University in...  degree        NaN
#
#    cb_url  rank           created_at           updated_at  \
# 0     NaN   NaN  2008-02-19 17:58:31  2018-02-13 01:40:03
# 1     NaN   NaN  2008-02-19 17:58:31  2018-02-13 01:39:57
#
#                             person_uuid person_name  \
# 0  4897dba9-3141-ecc0-2c4b-c9d844e6440f  John Green
# 1  4897dba9-3141-ecc0-2c4b-c9d844e6440f  John Green
#
#                        institution_uuid                    institution_name  \
# 0  1eab62d2-15d9-0db7-930f-2aa77d4688e1                   Boston University
# 1  6ae9957a-8fb4-0ab1-73fa-dd547c4d3da4  Washington University in St. Louis
#
# ...

# %%
df_degree.shape
# Out:
# (354243, 17)

# %%
df_des.head(2)
# Out:
#                                    uuid            name    type  \
# 0  ed13cd36-fe2b-3707-197b-0c2d56e37a71     Ben Elowitz  person
# 1  5ceca97b-493c-1446-6249-5aaa33464763  Kevin Flaherty  person
#
#         permalink                                            cb_url      rank  \
# 0     ben-elowitz     https://www.crunchbase.com/person/ben-elowitz   31844.0
# 1  kevin-flaherty  https://www.crunchbase.com/person/kevin-flaherty  330550.0
#
#             created_at           updated_at  \
# 0  2007-05-25 14:03:54  2018-06-09 04:33:22
# 1  2007-05-25 14:04:16  2018-02-12 23:14:37
#
#                                          description
# 0  Ben Elowitz is co-founder and CEO of [Wetpaint...
# 1  Brand development, creative agency management,...

# %%
df_people.head(2)
# Out:
#                                    uuid            name    type  \
# 0  ed13cd36-fe2b-3707-197b-0c2d56e37a71     Ben Elowitz  person
# 1  5ceca97b-493c-1446-6249-5aaa33464763  Kevin Flaherty  person
#
#         permalink                                            cb_url      rank  \
# 0     ben-elowitz     https://www.crunchbase.com/person/ben-elowitz   31844.0
# 1  kevin-flaherty  https://www.crunchbase.com/person/kevin-flaherty  330550.0
#
#             created_at           updated_at first_name last_name  ...  \
# 0  2007-05-25 14:03:54  2018-06-09 04:33:22        Ben   Elowitz  ...
# 1  2007-05-25 14:04:16  2018-02-12 23:14:37      Kevin  Flaherty  ...
#
#   state_code      region     city        featured_job_organization_uuid  \
# 0         WA  Washington  Seattle  cf253887-5eac-21a2-28d3-47db7311f7e9
# 1        NaN         NaN      NaN  789e5e4d-0c90-d06e-92a0-b800b461c3da
#
#   featured_job_organization_name featured_job_title  \
# ...

# %%
df_people.shape
# Out:
# (957089, 22)

# %%
df1=pd.merge(df_people, df_degree, left_on='name', right_on='person_name',how='left')

# %%
df1.shape
# Out:
# (1208153, 39)

# %%
df1.head()
# Out:
#                                  uuid_x          name_x  type_x  \
# 0  ed13cd36-fe2b-3707-197b-0c2d56e37a71     Ben Elowitz  person
# 1  ed13cd36-fe2b-3707-197b-0c2d56e37a71     Ben Elowitz  person
# 2  5ceca97b-493c-1446-6249-5aaa33464763  Kevin Flaherty  person
# 3  5ceca97b-493c-1446-6249-5aaa33464763  Kevin Flaherty  person
# 4  9f99a98a-aa97-b30b-0d36-db67c1d277e0    Raju Vegesna  person
#
#       permalink_x                                          cb_url_x    rank_x  \
# 0     ben-elowitz     https://www.crunchbase.com/person/ben-elowitz   31844.0
# 1     ben-elowitz     https://www.crunchbase.com/person/ben-elowitz   31844.0
# 2  kevin-flaherty  https://www.crunchbase.com/person/kevin-flaherty  330550.0
# 3  kevin-flaherty  https://www.crunchbase.com/person/kevin-flaherty  330550.0
# 4    raju-vegesna    https://www.crunchbase.com/person/raju-vegesna    5540.0
#
#           created_at_x         updated_at_x first_name last_name  ...  \
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1208153 entries, 0 to 1208152
# Data columns (total 39 columns):
# uuid_x                            1208153 non-null object
# name_x                            1208153 non-null object
# type_x                            1208153 non-null object
# permalink_x                       1208152 non-null object
# cb_url_x                          1208152 non-null object
# rank_x                            1205333 non-null float64
# created_at_x                      1208153 non-null object
# updated_at_x                      1208153 non-null object
# first_name                        1208113 non-null object
# last_name                         1208112 non-null object
# gender                            1194322 non-null object
# country_code                      737203 non-null object
# state_code                        412312 non-null object
# region                            695588 non-null object
# ...

# %%
df1=df1[['name_x','rank_x','gender','country_code','state_code','region','city','featured_job_organization_name','featured_job_title','name_y','institution_name','subject','degree_type','completed_on']]

# %%
df1.head(2)
# Out:
#         name_x   rank_x gender country_code state_code      region     city  \
# 0  Ben Elowitz  31844.0   male          USA         WA  Washington  Seattle
# 1  Ben Elowitz  31844.0   male          USA         WA  Washington  Seattle
#
#   featured_job_organization_name featured_job_title  \
# 0          Madrona Venture Group  Managing Director
# 1          Madrona Venture Group  Managing Director
#
#                                               name_y  \
# 0  BS  Electrical Engineering/Computer Science @ ...
# 1  BS  Applied Mathematics @ University of Califo...
#
#                      institution_name  \
# 0  University of California, Berkeley
# 1  University of California, Berkeley
#
#                                    subject degree_type completed_on
# 0  Electrical Engineering/Computer Science          BS   1994-01-01
# 1                      Applied Mathematics          BS   1994-01-01

# %%
df2=pd.merge(df1,df_des,left_on='name_x',right_on='name',how='left')

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2603869 entries, 0 to 2603868
# Data columns (total 23 columns):
# name_x                            object
# rank_x                            float64
# gender                            object
# country_code                      object
# state_code                        object
# region                            object
# city                              object
# featured_job_organization_name    object
# featured_job_title                object
# name_y                            object
# institution_name                  object
# subject                           object
# degree_type                       object
# completed_on                      object
# uuid                              object
# name                              object
# type                              object
# permalink                         object
# cb_url                            object
# rank                              float64
# ...

# %%
df_new=df2.drop(['uuid','name','type','permalink','cb_url','rank','created_at','updated_at'],axis=1)

# %%
df_new.head()
# Out:
#            name_x    rank_x gender country_code state_code      region  \
# 0     Ben Elowitz   31844.0   male          USA         WA  Washington
# 1     Ben Elowitz   31844.0   male          USA         WA  Washington
# 2  Kevin Flaherty  330550.0   male          NaN        NaN         NaN
# 3  Kevin Flaherty  330550.0   male          NaN        NaN         NaN
# 4  Kevin Flaherty  330550.0   male          NaN        NaN         NaN
#
#       city featured_job_organization_name featured_job_title  \
# 0  Seattle          Madrona Venture Group  Managing Director
# 1  Seattle          Madrona Venture Group  Managing Director
# 2      NaN                       DRSmedia        Team Member
# 3      NaN                       DRSmedia        Team Member
# 4      NaN                       DRSmedia        Team Member
#
#                                               name_y  \
# 0  BS  Electrical Engineering/Computer Science @ ...
# 1  BS  Applied Mathematics @ University of Califo...
# ...

# %%
df_new.to_csv(r'C:\Users\admin\Desktop\people_degree.csv')
